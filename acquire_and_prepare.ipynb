# %%
# IMPORTS
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from env import host, username, password

import acquire
import warnings
warnings.filterwarnings("ignore")

# %%
# returns df from acquire.py file
df = acquire.get_zillow_data()

# %%
# shows how many rows and columns
df.shape
# Out:
# (77380, 68)

# %%
# displays a list of every column title
df.columns
# Out:
# Index(['id', 'parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %%
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                    NaN                3.5  ...         6.059063e+13
# 1                    NaN                1.0  ...         6.111001e+13
# 2                    NaN                2.0  ...         6.059022e+13
# 3                    8.0                3.0  ...         6.037300e+13
# 4                    8.0                3.0  ...         6.037124e+13
#
#    logerror  transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0  0.025595       2017-01-01                  NaN                     NaN
# 1  0.055619       2017-01-01                  NaN                     NaN
# 2  0.005383       2017-01-01                  NaN                     NaN
# 3 -0.103410       2017-01-01                  NaN                     NaN
# 4  0.006940       2017-01-01              Central                     NaN
#
#    buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                NaN                  NaN  Single Family Residential
# 1                NaN                  NaN  Single Family Residential
# 2                NaN                  NaN  Single Family Residential
# 3                NaN              Central  Single Family Residential
# 4                NaN              Central                Condominium
#
#    storydesc  typeconstructiondesc
# 0        NaN                   NaN
# 1        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 4        NaN                   NaN
#
# [5 rows x 68 columns]

# %%
# shows the data types for columns
df.dtypes
# Out:
# id                            int64
# parcelid                      int64
# airconditioningtypeid       float64
# architecturalstyletypeid    float64
# basementsqft                float64
#                              ...
# buildingclassdesc            object
# heatingorsystemdesc          object
# propertylandusedesc          object
# storydesc                    object
# typeconstructiondesc         object
# Length: 68, dtype: object

# %%
# displays the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values)
acquire.overview(df)
# Out:
# --- Shape: (77380, 68)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77380 entries, 0 to 77379
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            77380 non-null  int64
#  1   parcelid                      77380 non-null  int64
#  2   airconditioningtypeid         24953 non-null  float64
#  3   architecturalstyletypeid      206 non-null    float64
#  4   basementsqft                  50 non-null     float64
#  5   bathroomcnt                   77380 non-null  float64
#  6   bedroomcnt                    77380 non-null  float64
#  7   buildingclasstypeid           15 non-null     float64
#  8   buildingqualitytypeid         49671 non-null  float64
#  9   calculatedbathnbr             76771 non-null  float64
#  10  decktypeid                    614 non-null    float64
#  11  finishedfloor1squarefeet      6023 non-null   float64
#  12  calculatedfinishedsquarefeet  77184 non-null  float64
#  13  finishedsquarefeet12          73748 non-null  float64
#  14  finishedsquarefeet13          41 non-null     float64
#  15  finishedsquarefeet15          3009 non-null   float64
#  16  finishedsquarefeet50          6023 non-null   float64
#  17  finishedsquarefeet6           386 non-null    float64
#  18  fips                          77380 non-null  float64
#  19  fireplacecnt                  8276 non-null   float64
#  20  fullbathcnt                   76771 non-null  float64
#  21  garagecarcnt                  25474 non-null  float64
#  22  garagetotalsqft               25474 non-null  float64
#  23  hashottuborspa                1538 non-null   float64
#  24  heatingorsystemtypeid         49439 non-null  float64
#  25  latitude                      77380 non-null  float64
#  26  longitude                     77380 non-null  float64
#  27  lotsizesquarefeet             69141 non-null  float64
#  28  poolcnt                       16137 non-null  float64
#  29  poolsizesum                   867 non-null    float64
#  30  pooltypeid10                  464 non-null    float64
#  31  pooltypeid2                   1074 non-null   float64
#  32  pooltypeid7                   15042 non-null  float64
#  33  propertycountylandusecode     77380 non-null  object
#  34  propertylandusetypeid         77380 non-null  float64
#  35  propertyzoningdesc            50330 non-null  object
#  36  rawcensustractandblock        77380 non-null  float64
#  37  regionidcity                  75909 non-null  float64
#  38  regionidcounty                77380 non-null  float64
#  39  regionidneighborhood          30890 non-null  float64
#  40  regionidzip                   77330 non-null  float64
#  41  roomcnt                       77380 non-null  float64
#  42  storytypeid                   50 non-null     float64
#  43  threequarterbathnbr           10096 non-null  float64
#  44  typeconstructiontypeid        222 non-null    float64
#  45  unitcnt                       50562 non-null  float64
#  46  yardbuildingsqft17            2388 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77117 non-null  float64
#  49  numberofstories               17560 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77268 non-null  float64
#  52  taxvaluedollarcnt             77379 non-null  float64
#  53  assessmentyear                77380 non-null  float64
#  54  landtaxvaluedollarcnt         77378 non-null  float64
#  55  taxamount                     77375 non-null  float64
#  56  taxdelinquencyflag            2886 non-null   object
#  57  taxdelinquencyyear            2886 non-null   float64
#  58  censustractandblock           77136 non-null  float64
#  59  logerror                      77380 non-null  float64
#  60  transactiondate               77380 non-null  object
#  61  airconditioningdesc           24953 non-null  object
#  62  architecturalstyledesc        206 non-null    object
#  63  buildingclassdesc             15 non-null     object
#  64  heatingorsystemdesc           49439 non-null  object
#  65  propertylandusedesc           77380 non-null  object
#  66  storydesc                     50 non-null     object
#  67  typeconstructiondesc          222 non-null    object
# dtypes: float64(55), int64(2), object(11)
# memory usage: 40.7+ MB
# --- Column Descriptions
#                   id      parcelid  airconditioningtypeid  \
# count   7.738000e+04  7.738000e+04           24953.000000
# unique           NaN           NaN                    NaN
# top              NaN           NaN                    NaN
# freq             NaN           NaN                    NaN
# mean    1.495126e+06  1.300715e+07               1.813289
# std     8.609057e+05  3.481368e+06               2.967894
# min     3.490000e+02  1.071186e+07               1.000000
# 25%     7.520500e+05  1.153830e+07               1.000000
# 50%     1.497870e+06  1.253155e+07               1.000000
# 75%     2.240480e+06  1.421184e+07               1.000000
# max     2.982274e+06  1.676893e+08              13.000000
#
#         architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                 206.000000     50.000000  77380.000000  77380.000000
# unique                       NaN           NaN           NaN           NaN
# top                          NaN           NaN           NaN           NaN
# freq                         NaN           NaN           NaN           NaN
# mean                    7.388350    679.720000      2.299134      3.053489
# std                     2.734542    689.703546      0.996657      1.139103
# min                     2.000000     38.000000      0.000000      0.000000
# 25%                     7.000000    273.000000      2.000000      2.000000
# 50%                     7.000000    515.000000      2.000000      3.000000
# 75%                     7.000000    796.500000      3.000000      4.000000
# max                    21.000000   3560.000000     18.000000     16.000000
#
#         buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  ...  \
# count             15.000000           49671.000000       76771.000000  ...
# unique                  NaN                    NaN                NaN  ...
# top                     NaN                    NaN                NaN  ...
# freq                    NaN                    NaN                NaN  ...
# mean               3.933333               6.534638           2.316871  ...
# std                0.258199               1.721933           0.979761  ...
# min                3.000000               1.000000           1.000000  ...
# 25%                4.000000               6.000000           2.000000  ...
# 50%                4.000000               6.000000           2.000000  ...
# 75%                4.000000               8.000000           3.000000  ...
# max                4.000000              12.000000          18.000000  ...
#
#         censustractandblock      logerror  transactiondate  \
# count          7.713600e+04  77380.000000            77380
# unique                  NaN           NaN              264
# top                     NaN           NaN       2017-06-30
# freq                    NaN           NaN             1189
# mean           6.049674e+13      0.016628              NaN
# std            1.535252e+12      0.170190              NaN
# min            6.037101e+13     -4.655420              NaN
# 25%            6.037311e+13     -0.024377              NaN
# 50%            6.037603e+13      0.006627              NaN
# 75%            6.059042e+13      0.039204              NaN
# max            4.830301e+14      5.262999              NaN
#
#         airconditioningdesc  architecturalstyledesc  \
# count                 24953                     206
# unique                    5                       5
# top                 Central            Contemporary
# freq                  23133                     172
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN
#
#                                      buildingclassdesc  heatingorsystemdesc  \
# count                                               15                49439
# unique                                               2                   10
# top     Buildings having wood or wood and steel frames              Central
# freq                                                14                33550
# mean                                               NaN                  NaN
# std                                                NaN                  NaN
# min                                                NaN                  NaN
# 25%                                                NaN                  NaN
# 50%                                                NaN                  NaN
# 75%                                                NaN                  NaN
# max                                                NaN                  NaN
#
#               propertylandusedesc  storydesc  typeconstructiondesc
# count                       77380         50                   222
# unique                         13          1                     4
# top     Single Family Residential   Basement                 Frame
# freq                        52319         50                   219
# mean                          NaN        NaN                   NaN
# std                           NaN        NaN                   NaN
# min                           NaN        NaN                   NaN
# 25%                           NaN        NaN                   NaN
# 50%                           NaN        NaN                   NaN
# 75%                           NaN        NaN                   NaN
# max                           NaN        NaN                   NaN
#
# [11 rows x 68 columns]

# %%
acquire.nulls_by_columns(df)
# Out:
#                           num_cols_missing  pct_cols_missing
# id                                       0          0.000000
# parcelid                                 0          0.000000
# airconditioningtypeid                52427          0.677526
# architecturalstyletypeid             77174          0.997338
# basementsqft                         77330          0.999354
# ...                                    ...               ...
# buildingclassdesc                    77365          0.999806
# heatingorsystemdesc                  27941          0.361088
# propertylandusedesc                      0          0.000000
# storydesc                            77330          0.999354
# typeconstructiondesc                 77158          0.997131
#
# [68 rows x 2 columns]

# %%
acquire.nulls_by_rows(df)
# Out:
# num_rows_missing  percent_missing
# 23                0.338235               2
# 24                0.352941              13
# 25                0.367647              24
# 26                0.382353              65
# 27                0.397059             316
# 28                0.411765             455
# 29                0.426471            5270
# 30                0.441176            3455
# 31                0.455882            9891
# 32                0.470588           12579
# 33                0.485294           14782
# 34                0.500000           13326
# 35                0.514706            5148
# 36                0.529412            5775
# 37                0.544118            3620
# 38                0.558824            1925
# 39                0.573529             285
# 40                0.588235             230
# 41                0.602941              29
# 42                0.617647              23
# 43                0.632353              28
# 44                0.647059              78
# 45                0.661765              50
# 46                0.676471               5
# 47                0.691176               3
# 48                0.705882               3
# dtype: int64

# %%
import prepare

# %% [markdown]
# # sets thresh hold to 75 percent nulls
# threshold = df.shape[0] * .50
#
# # remove columns with high nulls
# df = df.dropna(axis=1, thresh=threshold)
#
# df.columns

# %%
df = prepare.prep_zillow(df)
# Out:
# The following 34 columns were dropped because they were missing more    than 50.0% of data:
# ['airconditioningtypeid', 'architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedfloor1squarefeet', 'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50', 'finishedsquarefeet6', 'fireplacecnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'regionidneighborhood', 'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid', 'yardbuildingsqft17', 'yardbuildingsqft26', 'numberofstories', 'fireplaceflag', 'taxdelinquencyflag', 'taxdelinquencyyear', 'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc', 'storydesc', 'typeconstructiondesc']
#
# 0 rows were dropped because they were missing more than          50.0% of data
# yearbuilt converted to age.

# %%
df.head().T
# Out:
#                                           28              44              67  \
# parcelid                            12036177        12106936        11016518
# bathroomcnt                              2.0             2.0             2.0
# bedroomcnt                                 3               3               4
# calculatedfinishedsquarefeet            1851            1447            1625
# fips                                    6037            6037            6037
# latitude                          34103373.0      34166370.0      34282275.0
# longitude                       -118293280.0    -118151336.0    -118492692.0
# lotsizesquarefeet                       6714            7283            8427
# propertycountylandusecode               0100            0100            0100
# rawcensustractandblock              60371892        60374616        60371066
# regionidcity                           12447           47019           12447
# regionidzip                            96008           96291           96370
# structuretaxvaluedollarcnt             32264           57734           54667
# taxvaluedollarcnt                      85035           70755           97097
# landtaxvaluedollarcnt                  52771           13021           42430
# taxamount                               1232            1050            1307
# censustractandblock           60371892012001  60374616001002  60371066461002
# logerror                             0.20647        0.075156        -0.06047
# transactiondate                   2017-01-02      2017-01-02      2017-01-02
# age                                       97             116              61
# county                           Los Angeles     Los Angeles     Los Angeles
#
#                                           70              86
# parcelid                            11018202        12579560
# bathroomcnt                              1.0             1.0
# bedroomcnt                                 2               2
# calculatedfinishedsquarefeet             812            1027
# fips                                    6037            6037
# latitude                          34276431.0      33816016.0
# longitude                       -118447368.0    -118271776.0
# lotsizesquarefeet                       7150            5574
# propertycountylandusecode               0100            0100
# rawcensustractandblock              60371095        60375437
# regionidcity                           12447           10723
# regionidzip                            96366           96229
# structuretaxvaluedollarcnt             21513           27521
# taxvaluedollarcnt                      40746           49034
# landtaxvaluedollarcnt                  19233           21513
# taxamount                                668            1179
# censustractandblock           60371095003018  60375437025006
# logerror                            0.021262       -0.025721
# transactiondate                   2017-01-02      2017-01-02
# age                                      100              66
# county                           Los Angeles     Los Angeles

# %%
df.dtypes
# Out:
# parcelid                          int64
# bathroomcnt                     float64
# bedroomcnt                        int64
# calculatedfinishedsquarefeet      int64
# fips                              int64
# latitude                        float64
# longitude                       float64
# lotsizesquarefeet                 int64
# propertycountylandusecode        object
# rawcensustractandblock            int64
# regionidcity                      int64
# regionidzip                       int64
# structuretaxvaluedollarcnt        int64
# taxvaluedollarcnt                 int64
# landtaxvaluedollarcnt             int64
# taxamount                         int64
# censustractandblock               int64
# logerror                        float64
# transactiondate                  object
# age                               int64
# county                           object
# dtype: object

# %% [markdown]
# ### Explore leftover nulls

# %%
df.isnull().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedfinishedsquarefeet    0
# fips                            0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# rawcensustractandblock          0
# regionidcity                    0
# regionidzip                     0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# transactiondate                 0
# age                             0
# county                          0
# dtype: int64
