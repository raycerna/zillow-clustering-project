# %% [markdown]
# # Prepare

# %% [markdown]
# ### Project Requirements
#
# - Data Prep: Column data types are appropriate for the data they contain
# - Data Prep: Missing values are investigated and handled
# - Data Prep: Outliers are investigated and handled

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from env import get_db_url
import acquire
import warnings
warnings.filterwarnings("ignore")

# %%
df = acquire.get_zillow_data()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77380 entries, 0 to 77379
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            77380 non-null  int64
#  1   parcelid                      77380 non-null  int64
#  2   airconditioningtypeid         24953 non-null  float64
#  3   architecturalstyletypeid      206 non-null    float64
#  4   basementsqft                  50 non-null     float64
#  5   bathroomcnt                   77380 non-null  float64
#  6   bedroomcnt                    77380 non-null  float64
#  7   buildingclasstypeid           15 non-null     float64
#  8   buildingqualitytypeid         49671 non-null  float64
#  9   calculatedbathnbr             76771 non-null  float64
#  10  decktypeid                    614 non-null    float64
#  11  finishedfloor1squarefeet      6023 non-null   float64
#  12  calculatedfinishedsquarefeet  77184 non-null  float64
#  13  finishedsquarefeet12          73748 non-null  float64
#  14  finishedsquarefeet13          41 non-null     float64
#  15  finishedsquarefeet15          3009 non-null   float64
#  16  finishedsquarefeet50          6023 non-null   float64
#  17  finishedsquarefeet6           386 non-null    float64
#  18  fips                          77380 non-null  float64
#  19  fireplacecnt                  8276 non-null   float64
#  20  fullbathcnt                   76771 non-null  float64
#  21  garagecarcnt                  25474 non-null  float64
#  22  garagetotalsqft               25474 non-null  float64
#  23  hashottuborspa                1538 non-null   float64
#  24  heatingorsystemtypeid         49439 non-null  float64
#  25  latitude                      77380 non-null  float64
#  26  longitude                     77380 non-null  float64
#  27  lotsizesquarefeet             69141 non-null  float64
#  28  poolcnt                       16137 non-null  float64
#  29  poolsizesum                   867 non-null    float64
#  30  pooltypeid10                  464 non-null    float64
#  31  pooltypeid2                   1074 non-null   float64
#  32  pooltypeid7                   15042 non-null  float64
#  33  propertycountylandusecode     77380 non-null  object
#  34  propertylandusetypeid         77380 non-null  float64
#  35  propertyzoningdesc            50330 non-null  object
#  36  rawcensustractandblock        77380 non-null  float64
#  37  regionidcity                  75909 non-null  float64
#  38  regionidcounty                77380 non-null  float64
#  39  regionidneighborhood          30890 non-null  float64
#  40  regionidzip                   77330 non-null  float64
#  41  roomcnt                       77380 non-null  float64
#  42  storytypeid                   50 non-null     float64
#  43  threequarterbathnbr           10096 non-null  float64
#  44  typeconstructiontypeid        222 non-null    float64
#  45  unitcnt                       50562 non-null  float64
#  46  yardbuildingsqft17            2388 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77117 non-null  float64
#  49  numberofstories               17560 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77268 non-null  float64
#  52  taxvaluedollarcnt             77379 non-null  float64
#  53  assessmentyear                77380 non-null  float64
#  54  landtaxvaluedollarcnt         77378 non-null  float64
#  55  taxamount                     77375 non-null  float64
#  56  taxdelinquencyflag            2886 non-null   object
#  57  taxdelinquencyyear            2886 non-null   float64
#  58  censustractandblock           77136 non-null  float64
#  59  logerror                      77380 non-null  float64
#  60  transactiondate               77380 non-null  object
#  61  airconditioningdesc           24953 non-null  object
#  62  architecturalstyledesc        206 non-null    object
#  63  buildingclassdesc             15 non-null     object
#  64  heatingorsystemdesc           49439 non-null  object
#  65  propertylandusedesc           77380 non-null  object
#  66  storydesc                     50 non-null     object
#  67  typeconstructiondesc          222 non-null    object
# dtypes: float64(55), int64(2), object(11)
# memory usage: 40.7+ MB

# %%
# sets thresh hold to 50 percent nulls
threshold = df.shape[0] * .50

# remove columns with high nulls
df = df.dropna(axis=1, thresh=threshold)

df.columns
# Out:
# Index(['id', 'parcelid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fips', 'fullbathcnt', 'heatingorsystemtypeid',
#        'latitude', 'longitude', 'lotsizesquarefeet',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidzip', 'roomcnt', 'unitcnt', 'yearbuilt',
#        'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear',
#        'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock', 'logerror',
#        'transactiondate', 'heatingorsystemdesc', 'propertylandusedesc'],
#       dtype='object')

# %%
df.propertylandusedesc.value_counts()
# Out:
# Single Family Residential                     52319
# Condominium                                   19294
# Duplex (2 Units, Any Combination)              2009
# Planned Unit Development                       1944
# Quadruplex (4 Units, Any Combination)           727
# Triplex (3 Units, Any Combination)              535
# Cluster Home                                    333
# Mobile Home                                      74
# Manufactured, Modular, Prefabricated Homes       58
# Residential General                              37
# Cooperative                                      29
# Commercial/Office/Residential Mixed Used         15
# Townhouse                                         6
# Name: propertylandusedesc, dtype: int64

# %% [markdown]
# #### should only need to analyze single family residental

# %%
# only list single family residental
df = df [(df.propertylandusedesc == 'Single Family Residential')]

# %%
df.bedroomcnt.value_counts()
# Out:
# 3.0     23302
# 4.0     15210
# 2.0      8317
# 5.0      3967
# 6.0       634
# 1.0       611
# 0.0       135
# 7.0       106
# 8.0        24
# 9.0         8
# 10.0        2
# 14.0        1
# 11.0        1
# 12.0        1
# Name: bedroomcnt, dtype: int64

# %%
df.bathroomcnt.value_counts()
# Out:
# 2.0     21839
# 3.0     10650
# 1.0      9536
# 2.5      3932
# 4.0      2225
# 3.5       916
# 1.5       839
# 5.0       803
# 4.5       686
# 6.0       320
# 5.5       224
# 0.0       119
# 7.0        88
# 8.0        53
# 6.5        47
# 7.5        16
# 9.0        13
# 10.0        5
# 11.0        3
# 8.5         3
# 18.0        1
# 13.0        1
# Name: bathroomcnt, dtype: int64

# %%
### lets only anaylze >0 and <6
df = df[(df.bedroomcnt <= 6 ) & (df.bathroomcnt <= 6 ) & (df.bedroomcnt > 0 ) & (df.bathroomcnt > 0) ]

# %%
df.bedroomcnt.value_counts()
# Out:
# 3.0    23294
# 4.0    15189
# 2.0     8315
# 5.0     3891
# 1.0      607
# 6.0      545
# Name: bedroomcnt, dtype: int64

# %%
df.bathroomcnt.value_counts()
# Out:
# 2.0    21827
# 3.0    10621
# 1.0     9518
# 2.5     3930
# 4.0     2202
# 3.5      913
# 1.5      839
# 5.0      787
# 4.5      679
# 6.0      302
# 5.5      223
# Name: bathroomcnt, dtype: int64

# %%
# keep only properties less than 3000 square feet. same as regression project.
df = df[df.calculatedfinishedsquarefeet <= 3000 ]

# %%
# keep only properties less than 1m.
df = df[df.taxvaluedollarcnt <= 100000]

# %%
df.unitcnt.value_counts()
# Out:
# 1.0    4899
# Name: unitcnt, dtype: int64

# %%
df.roomcnt.value_counts()
#same as bedrooms. will drop
# Out:
# 0.0     4925
# 6.0      584
# 7.0      442
# 5.0      247
# 8.0      204
# 4.0       68
# 9.0       48
# 3.0        8
# 10.0       6
# 2.0        2
# 11.0       1
# Name: roomcnt, dtype: int64

# %%
df.calculatedbathnbr.value_counts()
# already showed in bathrooms as a float
# Out:
# 2.0    3593
# 1.0    2390
# 3.0     281
# 2.5     134
# 1.5     131
# 4.0       5
# 3.5       1
# Name: calculatedbathnbr, dtype: int64

# %%
df.propertylandusedesc.value_counts()
# Out:
# Single Family Residential    6535
# Name: propertylandusedesc, dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#             id  parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 28      707014  12036177          2.0         3.0                    4.0
# 44      930752  12106936          2.0         3.0                    6.0
# 67     1628261  11016518          2.0         4.0                    8.0
# 70     1061201  11018202          1.0         2.0                    4.0
# 86      843278  12579560          1.0         2.0                    4.0
# ...        ...       ...          ...         ...                    ...
# 77356   620802  12885530          1.0         2.0                    4.0
# 77365   347372  11608641          2.0         2.0                    6.0
# 77367  2747021  11318911          1.0         1.0                    5.0
# 77373  1373391  10722691          2.0         3.0                    6.0
# 77378  1843709  12773139          1.0         3.0                    4.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 28                   2.0                        1851.0                1851.0
# 44                   2.0                        1447.0                1447.0
# 67                   2.0                        1625.0                1625.0
# 70                   1.0                         812.0                 812.0
# 86                   1.0                        1027.0                1027.0
# ...                  ...                           ...                   ...
# 77356                1.0                         820.0                 820.0
# 77365                2.0                        1281.0                1281.0
# 77367                1.0                         624.0                 624.0
# 77373                2.0                        1570.0                1570.0
# 77378                1.0                        1032.0                1032.0
#
#          fips  fullbathcnt  ...  structuretaxvaluedollarcnt  \
# 28     6037.0          2.0  ...                     32264.0
# 44     6037.0          2.0  ...                     57734.0
# 67     6037.0          2.0  ...                     54667.0
# 70     6037.0          1.0  ...                     21513.0
# 86     6037.0          1.0  ...                     27521.0
# ...       ...          ...  ...                         ...
# 77356  6037.0          1.0  ...                     49067.0
# 77365  6037.0          2.0  ...                     24621.0
# 77367  6037.0          1.0  ...                     49024.0
# 77373  6037.0          2.0  ...                     46784.0
# 77378  6037.0          1.0  ...                     32797.0
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt taxamount  \
# 28               85035.0          2016.0                52771.0   1232.08
# 44               70755.0          2016.0                13021.0   1050.39
# 67               97097.0          2016.0                42430.0   1307.93
# 70               40746.0          2016.0                19233.0    668.70
# 86               49034.0          2016.0                21513.0   1179.11
# ...                  ...             ...                    ...       ...
# 77356            60841.0          2016.0                11774.0    904.27
# 77365            97499.0          2016.0                72878.0   1391.79
# 77367            81706.0          2016.0                32682.0   1131.24
# 77373            72026.0          2016.0                25242.0   1000.70
# 77378            49546.0          2016.0                16749.0    876.43
#
#        censustractandblock  logerror  transactiondate  heatingorsystemdesc  \
# 28            6.037189e+13  0.206470       2017-01-02           Floor/Wall
# 44            6.037462e+13  0.075156       2017-01-02           Floor/Wall
# 67            6.037107e+13 -0.060470       2017-01-02              Central
# 70            6.037110e+13  0.021262       2017-01-02           Floor/Wall
# 86            6.037544e+13 -0.025721       2017-01-02           Floor/Wall
# ...                    ...       ...              ...                  ...
# 77356         6.037403e+13  0.003457       2017-09-19           Floor/Wall
# 77365         6.037269e+13 -0.816510       2017-09-19              Central
# 77367         6.037901e+13  0.013268       2017-09-19           Floor/Wall
# 77373         6.037135e+13  0.081196       2017-09-19              Central
# 77378         6.037434e+13  0.037129       2017-09-21              Central
#
#              propertylandusedesc
# 28     Single Family Residential
# 44     Single Family Residential
# 67     Single Family Residential
# 70     Single Family Residential
# 86     Single Family Residential
# ...                          ...
# 77356  Single Family Residential
# 77365  Single Family Residential
# 77367  Single Family Residential
# 77373  Single Family Residential
# 77378  Single Family Residential
#
# [4716 rows x 34 columns]

# %%
df.shape
# Out:
# (4716, 34)

# %%
df =df.drop(columns= ['finishedsquarefeet12', 'fullbathcnt', 'calculatedbathnbr',
                      'propertyzoningdesc', 'unitcnt', 'propertylandusedesc',
                      'assessmentyear', 'roomcnt', 'regionidcounty', 'propertylandusetypeid',
                      'heatingorsystemtypeid', 'id', 'heatingorsystemdesc', 'buildingqualitytypeid'],axis=1)

# %%
df.shape
# Out:
# (4716, 20)

# %%
df.columns
# Out:
# Index(['parcelid', 'bathroomcnt', 'bedroomcnt', 'calculatedfinishedsquarefeet',
#        'fips', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'propertycountylandusecode', 'rawcensustractandblock', 'regionidcity',
#        'regionidzip', 'yearbuilt', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount',
#        'censustractandblock', 'logerror', 'transactiondate'],
#       dtype='object')

# %%
def overview(df):
    print('--- Shape: {}'.format(df.shape))
    print('--- Info')
    df.info()
    print('--- Column Descriptions')
    print(df.describe(include='all'))
    return df

# %%
overview(df)
# Out:
# --- Shape: (4716, 20)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4716 entries, 28 to 77378
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      4716 non-null   int64
#  1   bathroomcnt                   4716 non-null   float64
#  2   bedroomcnt                    4716 non-null   float64
#  3   calculatedfinishedsquarefeet  4716 non-null   float64
#  4   fips                          4716 non-null   float64
#  5   latitude                      4716 non-null   float64
#  6   longitude                     4716 non-null   float64
#  7   lotsizesquarefeet             4716 non-null   float64
#  8   propertycountylandusecode     4716 non-null   object
#  9   rawcensustractandblock        4716 non-null   float64
#  10  regionidcity                  4716 non-null   float64
#  11  regionidzip                   4716 non-null   float64
#  12  yearbuilt                     4716 non-null   float64
#  13  structuretaxvaluedollarcnt    4716 non-null   float64
#  14  taxvaluedollarcnt             4716 non-null   float64
#  15  landtaxvaluedollarcnt         4716 non-null   float64
#  16  taxamount                     4716 non-null   float64
#  17  censustractandblock           4716 non-null   float64
#  18  logerror                      4716 non-null   float64
#  19  transactiondate               4716 non-null   object
# dtypes: float64(17), int64(1), object(2)
# memory usage: 773.7+ KB
# --- Column Descriptions
#             parcelid  bathroomcnt   bedroomcnt  calculatedfinishedsquarefeet  \
# count   4.716000e+03  4716.000000  4716.000000                   4716.000000
# unique           NaN          NaN          NaN                           NaN
# top              NaN          NaN          NaN                           NaN
# freq             NaN          NaN          NaN                           NaN
# mean    1.199163e+07     1.614292     2.865352                   1309.437871
# std     7.050041e+05     0.562414     0.729837                    346.438490
# min     1.071191e+07     1.000000     1.000000                    360.000000
# 25%     1.129231e+07     1.000000     2.000000                   1072.750000
# 50%     1.211850e+07     2.000000     3.000000                   1275.000000
# 75%     1.260653e+07     2.000000     3.000000                   1522.000000
# max     1.309954e+07     4.000000     6.000000                   2986.000000
#
#           fips      latitude     longitude  lotsizesquarefeet  \
# count   4716.0  4.716000e+03  4.716000e+03       4.716000e+03
# unique     NaN           NaN           NaN                NaN
# top        NaN           NaN           NaN                NaN
# freq       NaN           NaN           NaN                NaN
# mean    6037.0  3.409145e+07 -1.181925e+08       8.963446e+03
# std        0.0  2.256292e+05  1.951818e+05       3.332909e+04
# min     6037.0  3.334085e+07 -1.187206e+08       9.310000e+02
# 25%     6037.0  3.393099e+07 -1.183250e+08       5.473000e+03
# 50%     6037.0  3.405182e+07 -1.181736e+08       6.400000e+03
# 75%     6037.0  3.418222e+07 -1.180778e+08       7.582500e+03
# max     6037.0  3.476829e+07 -1.176665e+08       1.774617e+06
#
#        propertycountylandusecode  rawcensustractandblock   regionidcity  \
# count                       4716            4.716000e+03    4716.000000
# unique                         6                     NaN            NaN
# top                         0100                     NaN            NaN
# freq                        4371                     NaN            NaN
# mean                         NaN            6.037448e+07   38033.710348
# std                          NaN            2.261466e+03   64364.805336
# min                          NaN            6.037101e+07    3491.000000
# 25%                          NaN            6.037241e+07   12447.000000
# 50%                          NaN            6.037462e+07   14634.000000
# 75%                          NaN            6.037555e+07   45457.000000
# max                          NaN            6.037980e+07  396556.000000
#
#           regionidzip    yearbuilt  structuretaxvaluedollarcnt  \
# count     4716.000000  4716.000000                 4716.000000
# unique            NaN          NaN                         NaN
# top               NaN          NaN                         NaN
# freq              NaN          NaN                         NaN
# mean     96424.417515  1948.943384                38972.040076
# std       4431.246479    15.514915                16629.141597
# min      95982.000000  1885.000000                  302.000000
# 25%      96124.000000  1942.000000                26689.000000
# 50%      96265.000000  1952.000000                37913.000000
# 75%      96469.000000  1956.000000                50713.000000
# max     399675.000000  2010.000000                84896.000000
#
#         taxvaluedollarcnt  landtaxvaluedollarcnt     taxamount  \
# count         4716.000000            4716.000000   4716.000000
# unique                NaN                    NaN           NaN
# top                   NaN                    NaN           NaN
# freq                  NaN                    NaN           NaN
# mean         65709.689143           26737.649067   1147.220240
# std          19542.219744           12864.401232    616.334294
# min           3254.000000             161.000000    120.840000
# 25%          51106.000000           17402.000000    880.992500
# 50%          66843.000000           23579.000000   1085.330000
# 75%          80924.250000           33232.500000   1277.822500
# max          99995.000000           89096.000000  13096.410000
#
#         censustractandblock     logerror transactiondate
# count          4.716000e+03  4716.000000            4716
# unique                  NaN          NaN             196
# top                     NaN          NaN      2017-06-30
# freq                    NaN          NaN              82
# mean           6.037449e+13     0.026457             NaN
# std            2.260834e+09     0.199969             NaN
# min            6.037101e+13    -1.341564             NaN
# 25%            6.037242e+13    -0.032462             NaN
# 50%            6.037462e+13     0.006296             NaN
# 75%            6.037555e+13     0.049584             NaN
# max            6.037980e+13     3.100913             NaN
#        parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 28     12036177          2.0         3.0                        1851.0
# 44     12106936          2.0         3.0                        1447.0
# 67     11016518          2.0         4.0                        1625.0
# 70     11018202          1.0         2.0                         812.0
# 86     12579560          1.0         2.0                        1027.0
# ...         ...          ...         ...                           ...
# 77356  12885530          1.0         2.0                         820.0
# 77365  11608641          2.0         2.0                        1281.0
# 77367  11318911          1.0         1.0                         624.0
# 77373  10722691          2.0         3.0                        1570.0
# 77378  12773139          1.0         3.0                        1032.0
#
#          fips    latitude    longitude  lotsizesquarefeet  \
# 28     6037.0  34103373.0 -118293280.0             6714.0
# 44     6037.0  34166370.0 -118151336.0             7283.0
# 67     6037.0  34282275.0 -118492692.0             8427.0
# 70     6037.0  34276431.0 -118447368.0             7150.0
# 86     6037.0  33816016.0 -118271776.0             5574.0
# ...       ...         ...          ...                ...
# 77356  6037.0  34044147.0 -117762663.0             5717.0
# 77365  6037.0  34032660.0 -118400587.0            12000.0
# 77367  6037.0  34667122.0 -118222003.0            45398.0
# 77373  6037.0  34194943.0 -118629218.0             7499.0
# 77378  6037.0  34040895.0 -118038169.0             5074.0
#
#       propertycountylandusecode  rawcensustractandblock  regionidcity  \
# 28                         0100            6.037189e+07       12447.0
# 44                         0100            6.037462e+07       47019.0
# 67                         0100            6.037107e+07       12447.0
# 70                         0100            6.037110e+07       12447.0
# 86                         0100            6.037544e+07       10723.0
# ...                         ...                     ...           ...
# 77356                      0100            6.037403e+07       20008.0
# 77365                      0100            6.037269e+07       12447.0
# 77367                      0100            6.037901e+07        5534.0
# 77373                      0100            6.037135e+07       12447.0
# 77378                      0100            6.037434e+07       36502.0
#
#        regionidzip  yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 28         96008.0     1920.0                     32264.0            85035.0
# 44         96291.0     1901.0                     57734.0            70755.0
# 67         96370.0     1956.0                     54667.0            97097.0
# 70         96366.0     1917.0                     21513.0            40746.0
# 86         96229.0     1951.0                     27521.0            49034.0
# ...            ...        ...                         ...                ...
# 77356      96506.0     1949.0                     49067.0            60841.0
# 77365      96015.0     1954.0                     24621.0            97499.0
# 77367      97319.0     1944.0                     49024.0            81706.0
# 77373      96342.0     1958.0                     46784.0            72026.0
# 77378      96480.0     1954.0                     32797.0            49546.0
#
#        landtaxvaluedollarcnt  taxamount  censustractandblock  logerror  \
# 28                   52771.0    1232.08         6.037189e+13  0.206470
# 44                   13021.0    1050.39         6.037462e+13  0.075156
# 67                   42430.0    1307.93         6.037107e+13 -0.060470
# 70                   19233.0     668.70         6.037110e+13  0.021262
# 86                   21513.0    1179.11         6.037544e+13 -0.025721
# ...                      ...        ...                  ...       ...
# 77356                11774.0     904.27         6.037403e+13  0.003457
# 77365                72878.0    1391.79         6.037269e+13 -0.816510
# 77367                32682.0    1131.24         6.037901e+13  0.013268
# 77373                25242.0    1000.70         6.037135e+13  0.081196
# 77378                16749.0     876.43         6.037434e+13  0.037129
#
#       transactiondate
# 28         2017-01-02
# 44         2017-01-02
# 67         2017-01-02
# 70         2017-01-02
# 86         2017-01-02
# ...               ...
# 77356      2017-09-19
# 77365      2017-09-19
# 77367      2017-09-19
# 77373      2017-09-19
# 77378      2017-09-21
#
# [4716 rows x 20 columns]

# %%
#adding same features from regression project
df['transactiondate'] = df.transactiondate.astype('str')
df['transaction_month'] = df.transactiondate.str.split('-',expand=True)[1]

# %%
df
# Out:
#        parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 28     12036177          2.0         3.0                        1851.0
# 44     12106936          2.0         3.0                        1447.0
# 67     11016518          2.0         4.0                        1625.0
# 70     11018202          1.0         2.0                         812.0
# 86     12579560          1.0         2.0                        1027.0
# ...         ...          ...         ...                           ...
# 77356  12885530          1.0         2.0                         820.0
# 77365  11608641          2.0         2.0                        1281.0
# 77367  11318911          1.0         1.0                         624.0
# 77373  10722691          2.0         3.0                        1570.0
# 77378  12773139          1.0         3.0                        1032.0
#
#          fips    latitude    longitude  lotsizesquarefeet  \
# 28     6037.0  34103373.0 -118293280.0             6714.0
# 44     6037.0  34166370.0 -118151336.0             7283.0
# 67     6037.0  34282275.0 -118492692.0             8427.0
# 70     6037.0  34276431.0 -118447368.0             7150.0
# 86     6037.0  33816016.0 -118271776.0             5574.0
# ...       ...         ...          ...                ...
# 77356  6037.0  34044147.0 -117762663.0             5717.0
# 77365  6037.0  34032660.0 -118400587.0            12000.0
# 77367  6037.0  34667122.0 -118222003.0            45398.0
# 77373  6037.0  34194943.0 -118629218.0             7499.0
# 77378  6037.0  34040895.0 -118038169.0             5074.0
#
#       propertycountylandusecode  rawcensustractandblock  ...  regionidzip  \
# 28                         0100            6.037189e+07  ...      96008.0
# 44                         0100            6.037462e+07  ...      96291.0
# 67                         0100            6.037107e+07  ...      96370.0
# 70                         0100            6.037110e+07  ...      96366.0
# 86                         0100            6.037544e+07  ...      96229.0
# ...                         ...                     ...  ...          ...
# 77356                      0100            6.037403e+07  ...      96506.0
# 77365                      0100            6.037269e+07  ...      96015.0
# 77367                      0100            6.037901e+07  ...      97319.0
# 77373                      0100            6.037135e+07  ...      96342.0
# 77378                      0100            6.037434e+07  ...      96480.0
#
#        yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 28        1920.0                     32264.0            85035.0
# 44        1901.0                     57734.0            70755.0
# 67        1956.0                     54667.0            97097.0
# 70        1917.0                     21513.0            40746.0
# 86        1951.0                     27521.0            49034.0
# ...          ...                         ...                ...
# 77356     1949.0                     49067.0            60841.0
# 77365     1954.0                     24621.0            97499.0
# 77367     1944.0                     49024.0            81706.0
# 77373     1958.0                     46784.0            72026.0
# 77378     1954.0                     32797.0            49546.0
#
#        landtaxvaluedollarcnt  taxamount  censustractandblock  logerror  \
# 28                   52771.0    1232.08         6.037189e+13  0.206470
# 44                   13021.0    1050.39         6.037462e+13  0.075156
# 67                   42430.0    1307.93         6.037107e+13 -0.060470
# 70                   19233.0     668.70         6.037110e+13  0.021262
# 86                   21513.0    1179.11         6.037544e+13 -0.025721
# ...                      ...        ...                  ...       ...
# 77356                11774.0     904.27         6.037403e+13  0.003457
# 77365                72878.0    1391.79         6.037269e+13 -0.816510
# 77367                32682.0    1131.24         6.037901e+13  0.013268
# 77373                25242.0    1000.70         6.037135e+13  0.081196
# 77378                16749.0     876.43         6.037434e+13  0.037129
#
#        transactiondate transaction_month
# 28          2017-01-02                01
# 44          2017-01-02                01
# 67          2017-01-02                01
# 70          2017-01-02                01
# 86          2017-01-02                01
# ...                ...               ...
# 77356       2017-09-19                09
# 77365       2017-09-19                09
# 77367       2017-09-19                09
# 77373       2017-09-19                09
# 77378       2017-09-21                09
#
# [4716 rows x 21 columns]

# %%
df['tax_rate'] = (df.taxamount/df.taxvaluedollarcnt) * 100

# %%
df
# Out:
#        parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 28     12036177          2.0         3.0                        1851.0
# 44     12106936          2.0         3.0                        1447.0
# 67     11016518          2.0         4.0                        1625.0
# 70     11018202          1.0         2.0                         812.0
# 86     12579560          1.0         2.0                        1027.0
# ...         ...          ...         ...                           ...
# 77356  12885530          1.0         2.0                         820.0
# 77365  11608641          2.0         2.0                        1281.0
# 77367  11318911          1.0         1.0                         624.0
# 77373  10722691          2.0         3.0                        1570.0
# 77378  12773139          1.0         3.0                        1032.0
#
#          fips    latitude    longitude  lotsizesquarefeet  \
# 28     6037.0  34103373.0 -118293280.0             6714.0
# 44     6037.0  34166370.0 -118151336.0             7283.0
# 67     6037.0  34282275.0 -118492692.0             8427.0
# 70     6037.0  34276431.0 -118447368.0             7150.0
# 86     6037.0  33816016.0 -118271776.0             5574.0
# ...       ...         ...          ...                ...
# 77356  6037.0  34044147.0 -117762663.0             5717.0
# 77365  6037.0  34032660.0 -118400587.0            12000.0
# 77367  6037.0  34667122.0 -118222003.0            45398.0
# 77373  6037.0  34194943.0 -118629218.0             7499.0
# 77378  6037.0  34040895.0 -118038169.0             5074.0
#
#       propertycountylandusecode  rawcensustractandblock  ...  yearbuilt  \
# 28                         0100            6.037189e+07  ...     1920.0
# 44                         0100            6.037462e+07  ...     1901.0
# 67                         0100            6.037107e+07  ...     1956.0
# 70                         0100            6.037110e+07  ...     1917.0
# 86                         0100            6.037544e+07  ...     1951.0
# ...                         ...                     ...  ...        ...
# 77356                      0100            6.037403e+07  ...     1949.0
# 77365                      0100            6.037269e+07  ...     1954.0
# 77367                      0100            6.037901e+07  ...     1944.0
# 77373                      0100            6.037135e+07  ...     1958.0
# 77378                      0100            6.037434e+07  ...     1954.0
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 28                        32264.0            85035.0                52771.0
# 44                        57734.0            70755.0                13021.0
# 67                        54667.0            97097.0                42430.0
# 70                        21513.0            40746.0                19233.0
# 86                        27521.0            49034.0                21513.0
# ...                           ...                ...                    ...
# 77356                     49067.0            60841.0                11774.0
# 77365                     24621.0            97499.0                72878.0
# 77367                     49024.0            81706.0                32682.0
# 77373                     46784.0            72026.0                25242.0
# 77378                     32797.0            49546.0                16749.0
#
#        taxamount  censustractandblock  logerror  transactiondate  \
# 28       1232.08         6.037189e+13  0.206470       2017-01-02
# 44       1050.39         6.037462e+13  0.075156       2017-01-02
# 67       1307.93         6.037107e+13 -0.060470       2017-01-02
# 70        668.70         6.037110e+13  0.021262       2017-01-02
# 86       1179.11         6.037544e+13 -0.025721       2017-01-02
# ...          ...                  ...       ...              ...
# 77356     904.27         6.037403e+13  0.003457       2017-09-19
# 77365    1391.79         6.037269e+13 -0.816510       2017-09-19
# 77367    1131.24         6.037901e+13  0.013268       2017-09-19
# 77373    1000.70         6.037135e+13  0.081196       2017-09-19
# 77378     876.43         6.037434e+13  0.037129       2017-09-21
#
#        transaction_month  tax_rate
# 28                    01  1.448909
# 44                    01  1.484545
# 67                    01  1.347034
# 70                    01  1.641143
# 86                    01  2.404678
# ...                  ...       ...
# 77356                 09  1.486284
# 77365                 09  1.427492
# 77367                 09  1.384525
# 77373                 09  1.389359
# 77378                 09  1.768922
#
# [4716 rows x 22 columns]

# %%
    df['yearbuilt'] = df['yearbuilt'].astype(int)
    df["bedroomcnt"] = df["bedroomcnt"].astype(int)
    df["calculatedfinishedsquarefeet"] = df["calculatedfinishedsquarefeet"].astype(int)
    df["fips"] = df["fips"].astype(int)
    df["lotsizesquarefeet"] = df["lotsizesquarefeet"].astype(int)
    df["rawcensustractandblock"] = df["rawcensustractandblock"].astype(int)
    df["regionidcity"] = df["regionidcity"].astype(int)
    df["regionidzip"] = df["regionidzip"].astype(int)
    df["censustractandblock"] = df["censustractandblock"].astype(int)
    df["structuretaxvaluedollarcnt"] = df["structuretaxvaluedollarcnt"].astype(int)
    df["taxvaluedollarcnt"] = df["taxvaluedollarcnt"].astype(int)
    df["landtaxvaluedollarcnt"] = df["landtaxvaluedollarcnt"].astype(int)
    df["taxamount"] = df["taxamount"].astype(int)
    df.yearbuilt = df.yearbuilt.astype(object) 
    df['age'] = 2017-df['yearbuilt']
    df = df.drop(columns='yearbuilt')
    df['age'] = df['age'].astype('int')

# %%
overview(df)
# Out:
# --- Shape: (4716, 22)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4716 entries, 28 to 77378
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      4716 non-null   int64
#  1   bathroomcnt                   4716 non-null   float64
#  2   bedroomcnt                    4716 non-null   int64
#  3   calculatedfinishedsquarefeet  4716 non-null   int64
#  4   fips                          4716 non-null   int64
#  5   latitude                      4716 non-null   float64
#  6   longitude                     4716 non-null   float64
#  7   lotsizesquarefeet             4716 non-null   int64
#  8   propertycountylandusecode     4716 non-null   object
#  9   rawcensustractandblock        4716 non-null   int64
#  10  regionidcity                  4716 non-null   int64
#  11  regionidzip                   4716 non-null   int64
#  12  structuretaxvaluedollarcnt    4716 non-null   int64
#  13  taxvaluedollarcnt             4716 non-null   int64
#  14  landtaxvaluedollarcnt         4716 non-null   int64
#  15  taxamount                     4716 non-null   int64
#  16  censustractandblock           4716 non-null   int64
#  17  logerror                      4716 non-null   float64
#  18  transactiondate               4716 non-null   object
#  19  transaction_month             4716 non-null   object
#  20  tax_rate                      4716 non-null   float64
#  21  age                           4716 non-null   int64
# dtypes: float64(5), int64(14), object(3)
# memory usage: 847.4+ KB
# --- Column Descriptions
#             parcelid  bathroomcnt   bedroomcnt  calculatedfinishedsquarefeet  \
# count   4.716000e+03  4716.000000  4716.000000                   4716.000000
# unique           NaN          NaN          NaN                           NaN
# top              NaN          NaN          NaN                           NaN
# freq             NaN          NaN          NaN                           NaN
# mean    1.199163e+07     1.614292     2.865352                   1309.437871
# std     7.050041e+05     0.562414     0.729837                    346.438490
# min     1.071191e+07     1.000000     1.000000                    360.000000
# 25%     1.129231e+07     1.000000     2.000000                   1072.750000
# 50%     1.211850e+07     2.000000     3.000000                   1275.000000
# 75%     1.260653e+07     2.000000     3.000000                   1522.000000
# max     1.309954e+07     4.000000     6.000000                   2986.000000
#
#           fips      latitude     longitude  lotsizesquarefeet  \
# count   4716.0  4.716000e+03  4.716000e+03       4.716000e+03
# unique     NaN           NaN           NaN                NaN
# top        NaN           NaN           NaN                NaN
# freq       NaN           NaN           NaN                NaN
# mean    6037.0  3.409145e+07 -1.181925e+08       8.963446e+03
# std        0.0  2.256292e+05  1.951818e+05       3.332909e+04
# min     6037.0  3.334085e+07 -1.187206e+08       9.310000e+02
# 25%     6037.0  3.393099e+07 -1.183250e+08       5.473000e+03
# 50%     6037.0  3.405182e+07 -1.181736e+08       6.400000e+03
# 75%     6037.0  3.418222e+07 -1.180778e+08       7.582500e+03
# max     6037.0  3.476829e+07 -1.176665e+08       1.774617e+06
#
#        propertycountylandusecode  rawcensustractandblock  ...  \
# count                       4716            4.716000e+03  ...
# unique                         6                     NaN  ...
# top                         0100                     NaN  ...
# freq                        4371                     NaN  ...
# mean                         NaN            6.037448e+07  ...
# std                          NaN            2.261467e+03  ...
# min                          NaN            6.037101e+07  ...
# 25%                          NaN            6.037241e+07  ...
# 50%                          NaN            6.037462e+07  ...
# 75%                          NaN            6.037555e+07  ...
# max                          NaN            6.037980e+07  ...
#
#         structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# count                  4716.000000        4716.000000            4716.000000
# unique                         NaN                NaN                    NaN
# top                            NaN                NaN                    NaN
# freq                           NaN                NaN                    NaN
# mean                  38972.040076       65709.689143           26737.649067
# std                   16629.141597       19542.219744           12864.401232
# min                     302.000000        3254.000000             161.000000
# 25%                   26689.000000       51106.000000           17402.000000
# 50%                   37913.000000       66843.000000           23579.000000
# 75%                   50713.000000       80924.250000           33232.500000
# max                   84896.000000       99995.000000           89096.000000
#
#            taxamount  censustractandblock     logerror  transactiondate  \
# count    4716.000000         4.716000e+03  4716.000000             4716
# unique           NaN                  NaN          NaN              196
# top              NaN                  NaN          NaN       2017-06-30
# freq             NaN                  NaN          NaN               82
# mean     1146.733673         6.037449e+13     0.026457              NaN
# std       616.336876         2.260834e+09     0.199969              NaN
# min       120.000000         6.037101e+13    -1.341564              NaN
# 25%       880.750000         6.037242e+13    -0.032462              NaN
# 50%      1085.000000         6.037462e+13     0.006296              NaN
# 75%      1277.000000         6.037555e+13     0.049584              NaN
# max     13096.000000         6.037980e+13     3.100913              NaN
#
#         transaction_month     tax_rate          age
# count                4716  4716.000000  4716.000000
# unique                  9          NaN          NaN
# top                    06          NaN          NaN
# freq                  673          NaN          NaN
# mean                  NaN     1.835458    68.056616
# std                   NaN     1.442776    15.514915
# min                   NaN     0.148926     7.000000
# 25%                   NaN     1.399968    61.000000
# 50%                   NaN     1.615434    65.000000
# 75%                   NaN     1.964035    75.000000
# max                   NaN    49.364739   132.000000
#
# [11 rows x 22 columns]
#        parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  fips  \
# 28     12036177          2.0           3                          1851  6037
# 44     12106936          2.0           3                          1447  6037
# 67     11016518          2.0           4                          1625  6037
# 70     11018202          1.0           2                           812  6037
# 86     12579560          1.0           2                          1027  6037
# ...         ...          ...         ...                           ...   ...
# 77356  12885530          1.0           2                           820  6037
# 77365  11608641          2.0           2                          1281  6037
# 77367  11318911          1.0           1                           624  6037
# 77373  10722691          2.0           3                          1570  6037
# 77378  12773139          1.0           3                          1032  6037
#
#          latitude    longitude  lotsizesquarefeet propertycountylandusecode  \
# 28     34103373.0 -118293280.0               6714                      0100
# 44     34166370.0 -118151336.0               7283                      0100
# 67     34282275.0 -118492692.0               8427                      0100
# 70     34276431.0 -118447368.0               7150                      0100
# 86     33816016.0 -118271776.0               5574                      0100
# ...           ...          ...                ...                       ...
# 77356  34044147.0 -117762663.0               5717                      0100
# 77365  34032660.0 -118400587.0              12000                      0100
# 77367  34667122.0 -118222003.0              45398                      0100
# 77373  34194943.0 -118629218.0               7499                      0100
# 77378  34040895.0 -118038169.0               5074                      0100
#
#        rawcensustractandblock  ...  structuretaxvaluedollarcnt  \
# 28                   60371892  ...                       32264
# 44                   60374616  ...                       57734
# 67                   60371066  ...                       54667
# 70                   60371095  ...                       21513
# 86                   60375437  ...                       27521
# ...                       ...  ...                         ...
# 77356                60374025  ...                       49067
# 77365                60372690  ...                       24621
# 77367                60379011  ...                       49024
# 77373                60371352  ...                       46784
# 77378                60374338  ...                       32797
#
#        taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount  \
# 28                 85035                  52771       1232
# 44                 70755                  13021       1050
# 67                 97097                  42430       1307
# 70                 40746                  19233        668
# 86                 49034                  21513       1179
# ...                  ...                    ...        ...
# 77356              60841                  11774        904
# 77365              97499                  72878       1391
# 77367              81706                  32682       1131
# 77373              72026                  25242       1000
# 77378              49546                  16749        876
#
#        censustractandblock  logerror  transactiondate  transaction_month  \
# 28          60371892012001  0.206470       2017-01-02                 01
# 44          60374616001002  0.075156       2017-01-02                 01
# 67          60371066461002 -0.060470       2017-01-02                 01
# 70          60371095003018  0.021262       2017-01-02                 01
# 86          60375437025006 -0.025721       2017-01-02                 01
# ...                    ...       ...              ...                ...
# 77356       60374025022022  0.003457       2017-09-19                 09
# 77365       60372690003005 -0.816510       2017-09-19                 09
# 77367       60379011012002  0.013268       2017-09-19                 09
# 77373       60371352011004  0.081196       2017-09-19                 09
# 77378       60374338022005  0.037129       2017-09-21                 09
#
#        tax_rate  age
# 28     1.448909   97
# 44     1.484545  116
# 67     1.347034   61
# 70     1.641143  100
# 86     2.404678   66
# ...         ...  ...
# 77356  1.486284   68
# 77365  1.427492   63
# 77367  1.384525   73
# 77373  1.389359   59
# 77378  1.768922   63
#
# [4716 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# calculatedfinishedsquarefeet    0
# fips                            0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# rawcensustractandblock          0
# regionidcity                    0
# regionidzip                     0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# transactiondate                 0
# transaction_month               0
# tax_rate                        0
# age                             0
# dtype: int64

# %%
def get_upper_outliers(s, k):
    '''
    Given a series and a cutoff value, k, returns the upper outliers for the
    series.

    The values returned will be either 0 (if the point is not an outlier), or a
    number that indicates how far away from the upper bound the observation is.
    '''
    q1, q3 = s.quantile([.25, .75])
    iqr = q3 - q1
    upper_bound = q3 + k * iqr
    return s.apply(lambda x: max([x - upper_bound, 0]))

def add_upper_outlier_columns(df, k):
    '''
    Add a column with the suffix _outliers for all the numeric columns
    in the given dataframe.
    '''
    # outlier_cols = {col + '_outliers': get_upper_outliers(df[col], k)
    #                 for col in df.select_dtypes('number')}
    # return df.assign(**outlier_cols)

    for col in df.select_dtypes('number'):
        df[col + '_outliers'] = get_upper_outliers(df[col], k)

    return df

add_upper_outlier_columns(df, k=1.5)

df.head()
# Out:
#     parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  fips  \
# 28  12036177          2.0           3                          1851  6037
# 44  12106936          2.0           3                          1447  6037
# 67  11016518          2.0           4                          1625  6037
# 70  11018202          1.0           2                           812  6037
# 86  12579560          1.0           2                          1027  6037
#
#       latitude    longitude  lotsizesquarefeet propertycountylandusecode  \
# 28  34103373.0 -118293280.0               6714                      0100
# 44  34166370.0 -118151336.0               7283                      0100
# 67  34282275.0 -118492692.0               8427                      0100
# 70  34276431.0 -118447368.0               7150                      0100
# 86  33816016.0 -118271776.0               5574                      0100
#
#     rawcensustractandblock  ...  regionidcity_outliers  regionidzip_outliers  \
# 28                60371892  ...                    0.0                   0.0
# 44                60374616  ...                    0.0                   0.0
# 67                60371066  ...                    0.0                   0.0
# 70                60371095  ...                    0.0                   0.0
# 86                60375437  ...                    0.0                   0.0
#
#     structuretaxvaluedollarcnt_outliers  taxvaluedollarcnt_outliers  \
# 28                                    0                           0
# 44                                    0                           0
# 67                                    0                           0
# 70                                    0                           0
# 86                                    0                           0
#
#     landtaxvaluedollarcnt_outliers  taxamount_outliers  \
# 28                             0.0                 0.0
# 44                             0.0                 0.0
# 67                             0.0                 0.0
# 70                             0.0                 0.0
# 86                             0.0                 0.0
#
#     censustractandblock_outliers  logerror_outliers tax_rate_outliers  \
# 28                             0           0.033818               0.0
# 44                             0           0.000000               0.0
# 67                             0           0.000000               0.0
# 70                             0           0.000000               0.0
# 86                             0           0.000000               0.0
#
#    age_outliers
# 28          1.0
# 44         20.0
# 67          0.0
# 70          4.0
# 86          0.0
#
# [5 rows x 41 columns]

# %%
outlier_cols = [col for col in df if col.endswith('_outliers')]
for col in outlier_cols:
    print('~~~\n' + col)
    data = df[col][df[col] > 0]
    print(data.describe())
# Out:
# ~~~
# parcelid_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: parcelid_outliers, dtype: float64
# ~~~
# bathroomcnt_outliers
# count    3.0
# mean     0.5
# std      0.0
# min      0.5
# 25%      0.5
# 50%      0.5
# 75%      0.5
# max      0.5
# Name: bathroomcnt_outliers, dtype: float64
# ~~~
# bedroomcnt_outliers
# count    56.000000
# mean      0.607143
# std       0.312094
# min       0.500000
# 25%       0.500000
# 50%       0.500000
# 75%       0.500000
# max       1.500000
# Name: bedroomcnt_outliers, dtype: float64
# ~~~
# calculatedfinishedsquarefeet_outliers
# count     66.000000
# mean     228.852273
# std      197.802819
# min        6.125000
# 25%       77.375000
# 50%      167.125000
# 75%      314.875000
# max      790.125000
# Name: calculatedfinishedsquarefeet_outliers, dtype: float64
# ~~~
# fips_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: fips_outliers, dtype: float64
# ~~~
# latitude_outliers
# count       437.000000
# mean      87974.264302
# std       52809.273236
# min         233.500000
# 25%       27617.500000
# 50%      108914.500000
# 75%      132754.500000
# max      209230.500000
# Name: latitude_outliers, dtype: float64
# ~~~
# longitude_outliers
# count        6.000000
# mean      9251.750000
# std      15425.274208
# min        728.750000
# 25%       2037.500000
# 50%       3808.750000
# 75%       4814.250000
# max      40567.750000
# Name: longitude_outliers, dtype: float64
# ~~~
# lotsizesquarefeet_outliers
# count    3.510000e+02
# mean     2.978342e+04
# std      1.177165e+05
# min      1.025000e+01
# 25%      1.494750e+03
# 50%      5.437250e+03
# 75%      1.873625e+04
# max      1.763870e+06
# Name: lotsizesquarefeet_outliers, dtype: float64
# ~~~
# rawcensustractandblock_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: rawcensustractandblock_outliers, dtype: float64
# ~~~
# regionidcity_outliers
# count       330.000000
# mean     130174.506061
# std      134851.145998
# min       18440.000000
# 25%       23253.000000
# 50%       23942.000000
# 75%      301082.000000
# max      301584.000000
# Name: regionidcity_outliers, dtype: float64
# ~~~
# regionidzip_outliers
# count       471.000000
# mean        977.644374
# std       13931.683027
# min         311.500000
# 25%         331.500000
# 50%         331.500000
# 75%         341.500000
# max      302688.500000
# Name: regionidzip_outliers, dtype: float64
# ~~~
# structuretaxvaluedollarcnt_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: structuretaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# taxvaluedollarcnt_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: taxvaluedollarcnt_outliers, dtype: float64
# ~~~
# landtaxvaluedollarcnt_outliers
# count      161.000000
# mean      8077.215839
# std       7317.533785
# min         17.750000
# 25%       3054.750000
# 50%       5960.750000
# 75%      11223.750000
# max      32117.750000
# Name: landtaxvaluedollarcnt_outliers, dtype: float64
# ~~~
# taxamount_outliers
# count      175.000000
# mean      1184.030714
# std       2039.111129
# min          1.625000
# 25%         77.125000
# 50%        169.625000
# 75%       1371.625000
# max      11224.625000
# Name: taxamount_outliers, dtype: float64
# ~~~
# censustractandblock_outliers
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: censustractandblock_outliers, dtype: float64
# ~~~
# logerror_outliers
# count    425.000000
# mean       0.253382
# std        0.394534
# min        0.000192
# 25%        0.038009
# 50%        0.132289
# 75%        0.277728
# max        2.928261
# Name: logerror_outliers, dtype: float64
# ~~~
# tax_rate_outliers
# count    208.000000
# mean       2.474059
# std        5.658231
# min        0.000763
# 25%        0.289304
# 50%        0.624805
# 75%        2.178232
# max       46.554605
# Name: tax_rate_outliers, dtype: float64
# ~~~
# age_outliers
# count    212.000000
# mean      10.033019
# std        6.495631
# min        1.000000
# 25%        6.000000
# 50%        9.500000
# 75%       13.000000
# max       36.000000
# Name: age_outliers, dtype: float64

# %%
#removing outliers
df = remove_outliers(df, 3, ['lotsizesquarefeet', 'structuretaxvaluedollarcnt','rawcensustractandblock'])

# %% [markdown]
# # Put all together in prepare.py
